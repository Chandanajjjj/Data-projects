# %%
import pandas as pd
df = pd.read_csv("/content/empdata.csv")

# %%
df.head()
# Out:
#    Empid           Ename    Salary         DOJ
# 0   1001          Ganesh   1000.00  10-10-2000
# 1   1002            Anil  23000.50   3/20/2002
# 2   1003          Gaurav       NaN  03-03-2002
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000

# %%
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_274b4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_274b4_level0_col0" class="col_heading level0 col0" >Empid</th>
#       <th id="T_274b4_level0_col1" class="col_heading level0 col1" >Ename</th>
#       <th id="T_274b4_level0_col2" class="col_heading level0 col2" >Salary</th>
#       <th id="T_274b4_level0_col3" class="col_heading level0 col3" >DOJ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_274b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_274b4_row0_col0" class="data row0 col0" >1001</td>
#       <td id="T_274b4_row0_col1" class="data row0 col1" >Ganesh</td>
#       <td id="T_274b4_row0_col2" class="data row0 col2" >1000.000000</td>
#       <td id="T_274b4_row0_col3" class="data row0 col3" >10-10-2000</td>
#     </tr>
#     <tr>
#       <th id="T_274b4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_274b4_row1_col0" class="data row1 col0" >1002</td>
#       <td id="T_274b4_row1_col1" class="data row1 col1" >Anil</td>
#       <td id="T_274b4_row1_col2" class="data row1 col2" >23000.500000</td>
#       <td id="T_274b4_row1_col3" class="data row1 col3" >3/20/2002</td>
#     </tr>
#     <tr>
#       <th id="T_274b4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_274b4_row2_col0" class="data row2 col0" >1003</td>
#       <td id="T_274b4_row2_col1" class="data row2 col1" >Gaurav</td>
#       <td id="T_274b4_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_274b4_row2_col3" class="data row2 col3" >03-03-2002</td>
#     </tr>
#     <tr>
#       <th id="T_274b4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_274b4_row3_col0" class="data row3 col0" >1004</td>
#       <td id="T_274b4_row3_col1" class="data row3 col1" >Hema Chandra</td>
#       <td id="T_274b4_row3_col2" class="data row3 col2" >16500.500000</td>
#       <td id="T_274b4_row3_col3" class="data row3 col3" >09-10-2000</td>
#     </tr>
#     <tr>
#       <th id="T_274b4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_274b4_row4_col0" class="data row4 col0" >1005</td>
#       <td id="T_274b4_row4_col1" class="data row4 col1" >Laxmi Prasanna</td>
#       <td id="T_274b4_row4_col2" class="data row4 col2" >12000.750000</td>
#       <td id="T_274b4_row4_col3" class="data row4 col3" >10-08-2000</td>
#     </tr>
#     <tr>
#       <th id="T_274b4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_274b4_row5_col0" class="data row5 col0" >1006</td>
#       <td id="T_274b4_row5_col1" class="data row5 col1" >Anant </td>
#       <td id="T_274b4_row5_col2" class="data row5 col2" >9999.990000</td>
#       <td id="T_274b4_row5_col3" class="data row5 col3" >09-09-1999</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.shape
# Out:
# (6, 4)

# %%
df.Empid
# Out:
# 0    1001
# 1    1002
# 2    1003
# 3    1004
# 4    1005
# 5    1006
# Name: Empid, dtype: int64

# %%
df.columns
# Out:
# Index(['Empid', 'Ename', 'Salary', 'DOJ'], dtype='object')

# %%
df.tail(2)
# Out:
#    Empid           Ename    Salary         DOJ
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000
# 5   1006          Anant    9999.99  09-09-1999

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Empid   6 non-null      int64
#  1   Ename   6 non-null      object
#  2   Salary  5 non-null      float64
#  3   DOJ     6 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 320.0+ bytes

# %%
df.size
# Out:
# 24

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    Empid           Ename    Salary         DOJ
# 0   1001          Ganesh   1000.00  10-10-2000
# 1   1002            Anil  23000.50   3/20/2002
# 2   1003          Gaurav       NaN  03-03-2002
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000
# 5   1006          Anant    9999.99  09-09-1999>

# %%
df.DOJ
# Out:
# 0    10-10-2000
# 1     3/20/2002
# 2    03-03-2002
# 3    09-10-2000
# 4    10-08-2000
# 5    09-09-1999
# Name: DOJ, dtype: object

# %%
df[["Empid","Ename"]]
# Out:
#    Empid           Ename
# 0   1001          Ganesh
# 1   1002            Anil
# 2   1003          Gaurav
# 3   1004    Hema Chandra
# 4   1005  Laxmi Prasanna
# 5   1006          Anant

# %%
df1 = df.append(df)
print('Dimensions of the original frame',df.shape)
print('Dimensions of the frame with duplicates',df1.shape)
#remove the duplicates
df1 = df1.drop_duplicates() #or use this statement df1.drop_dulipacte(inplace=True)
print ('dimension of the frame after after removing duplication',df1.shape)
# Out:
# Dimensions of the original frame (6, 4)
# Dimensions of the frame with duplicates (12, 4)
# dimension of the frame after after removing duplication (6, 4)
# <ipython-input-21-d9f26efe4b96>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df.append(df)

# %%
df.columns =[i.lower() for i in df]
print (df.columns)
# Out:
# Index(['empid', 'ename', 'salary', 'doj'], dtype='object')

# %%
df.columns=[i.upper() for i in df]
print(df.columns)
# Out:
# Index(['EMPID', 'ENAME', 'SALARY', 'DOJ'], dtype='object')

# %%
df.isna().sum()
#df.isna().sum()

#print(df.isnull())
print('the no. of nulls in each columns is \n',df.isnull().sum())
df.dropna(axis = 1, inplace = False)
# Out:
# the no. of nulls in each columns is
#  EMPID     0
# ENAME     0
# SALARY    1
# DOJ       0
# dtype: int64
#    EMPID           ENAME         DOJ
# 0   1001          Ganesh  10-10-2000
# 1   1002            Anil   3/20/2002
# 2   1003          Gaurav  03-03-2002
# 3   1004    Hema Chandra  09-10-2000
# 4   1005  Laxmi Prasanna  10-08-2000
# 5   1006          Anant   09-09-1999

# %%
print('highest Salary is',df['SALARY'].max())
print('lowest Salary is',df['SALARY'].min())
# Out:
# highest Salary is 23000.5
# lowest Salary is 1000.0

# %%
df.SALARY
# Out:
# 0     1000.00
# 1    23000.50
# 2         NaN
# 3    16500.50
# 4    12000.75
# 5     9999.99
# Name: SALARY, dtype: float64

# %%
df [df.SALARY > 20000]
# Out:
#    EMPID ENAME   SALARY        DOJ
# 1   1002  Anil  23000.5  3/20/2002

# %%
df[['EMPID','ENAME']] [df.SALARY > 20000]
# Out:
#    EMPID ENAME
# 1   1002  Anil

# %%
print ('average SALARY:',df.SALARY.mean())
df['ENAME'][df.SALARY > df.SALARY.mean()]
# Out:
# average SALARY: 12500.348
# 1            Anil
# 3    Hema Chandra
# Name: ENAME, dtype: object

# %%
df1['DOJ'] = pd.to_datetime(df1['DOJ'])  #convert DOJ to datatype
df1.info()
print('frame before sorting \n',df1)
df1.sort_values("DOJ", inplace = True)
print('frame after sorting \n',df1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 5 to 1
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Empid   6 non-null      int64
#  1   Ename   6 non-null      object
#  2   Salary  5 non-null      float64
#  3   DOJ     6 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 240.0+ bytes
# frame before sorting
#     Empid           Ename    Salary        DOJ
# 5   1006          Anant    9999.99 1999-09-09
# 3   1004    Hema Chandra  16500.50 2000-09-10
# 4   1005  Laxmi Prasanna  12000.75 2000-10-08
# 0   1001          Ganesh   1000.00 2000-10-10
# 2   1003          Gaurav       NaN 2002-03-03
# 1   1002            Anil  23000.50 2002-03-20
# frame after sorting
#     Empid           Ename    Salary        DOJ
# 5   1006          Anant    9999.99 1999-09-09
# 3   1004    Hema Chandra  16500.50 2000-09-10
# 4   1005  Laxmi Prasanna  12000.75 2000-10-08
# 0   1001          Ganesh   1000.00 2000-10-10
# 2   1003          Gaurav       NaN 2002-03-03
# 1   1002            Anil  23000.50 2002-03-20
